# %%
pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (0.10.11)
# Requirement already satisfied: absl-py in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (0.4.13)
# Requirement already satisfied: matplotlib in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (3.7.5)
# Requirement already satisfied: numpy in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (1.23.5)
# Requirement already satisfied: opencv-contrib-python in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe) (1.10.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from jax->mediapipe) (8.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->mediapipe) (6.4.5)
# Requirement already satisfied: pycparser in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: zipp>=3.20 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (10.4.0)
# Requirement already satisfied: pyperclip in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from mouseinfo->pyautogui) (1.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pynput==1.7.6
# Out:
# Requirement already satisfied: pynput==1.7.6 in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (1.7.6)
# Requirement already satisfied: six in c:\users\abhishek b o\appdata\local\programs\python\python38\lib\site-packages (from pynput==1.7.6) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import numpy as np
import util
import pyautogui
from pynput.mouse import Button, Controller
import random 
# import time

# %%
# pip install opencv-python

# %%
# pip install opencv-contrib-python

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.1.0
# aiofiles                     23.2.1
# altair                       5.4.1
# annotated-types              0.7.0
# anyio                        4.5.2
# asgiref                      3.8.1
# asttokens                    3.0.0
# astunparse                   1.6.3
# attrs                        25.3.0
# backcall                     0.2.0
# backports.zoneinfo           0.2.1
# beautifulsoup4               4.13.3
# blinker                      1.8.2
# cachetools                   5.5.2
# certifi                      2025.1.31
# cffi                         1.17.1
# charset-normalizer           3.4.1
# click                        8.1.8
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.1.1
# cycler                       0.12.1
# debugpy                      1.8.13
# decorator                    5.2.1
# Django                       4.2.16
# et_xmlfile                   2.0.0
# exceptiongroup               1.2.2
# executing                    2.2.0
# fastapi                      0.115.11
# ffmpy                        0.5.0
# filelock                     3.16.1
# Flask                        3.0.3
# flatbuffers                  25.2.10
# fonttools                    4.56.0
# frozendict                   2.4.6
# fsspec                       2025.3.0
# gast                         0.4.0
# gitdb                        4.0.12
# GitPython                    3.1.44
# google-auth                  2.38.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# gradio                       4.44.1
# gradio_client                1.3.0
# grpcio                       1.70.0
# gTTS                         2.5.4
# h11                          0.14.0
# h5py                         3.11.0
# httpcore                     1.0.7
# httpx                        0.28.1
# huggingface-hub              0.29.3
# idna                         3.10
# importlib_metadata           8.5.0
# importlib_resources          6.4.5
# ipykernel                    6.29.5
# ipython                      8.12.3
# itsdangerous                 2.2.0
# jax                          0.4.13
# jedi                         0.19.2
# Jinja2                       3.1.6
# joblib                       1.4.2
# jsonschema                   4.23.0
# jsonschema-specifications    2023.12.1
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# keras                        2.12.0
# kiwisolver                   1.4.7
# libclang                     18.1.1
# Markdown                     3.7
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.5
# matplotlib                   3.7.5
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# mediapipe                    0.10.11
# ml-dtypes                    0.2.0
# MouseInfo                    0.1.3
# multitasking                 0.0.11
# narwhals                     1.34.1
# nest-asyncio                 1.6.0
# numpy                        1.23.5
# oauthlib                     3.2.2
# opencv-contrib-python        4.11.0.86
# openpyxl                     3.1.5
# opt_einsum                   3.4.0
# orjson                       3.10.15
# packaging                    24.2
# pandas                       2.0.3
# parso                        0.8.4
# patsy                        1.0.1
# peewee                       3.17.9
# pickleshare                  0.7.5
# pillow                       10.4.0
# pip                          25.0.1
# pkgutil_resolve_name         1.3.10
# platformdirs                 4.3.6
# prompt_toolkit               3.0.50
# protobuf                     3.20.3
# psutil                       7.0.0
# pure_eval                    0.2.3
# pyarrow                      17.0.0
# pyasn1                       0.6.1
# pyasn1_modules               0.4.1
# PyAutoGUI                    0.9.54
# pycparser                    2.22
# pydantic                     2.10.6
# pydantic_core                2.27.2
# pydeck                       0.9.1
# pydub                        0.25.1
# PyGetWindow                  0.0.9
# Pygments                     2.19.1
# PyMsgBox                     1.0.9
# pynput                       1.7.6
# pyparsing                    3.1.4
# pyperclip                    1.9.0
# PyRect                       0.2.0
# PyScreeze                    1.0.1
# python-dateutil              2.9.0.post0
# python-multipart             0.0.20
# pytweening                   1.2.0
# pytz                         2025.1
# pywin32                      309
# PyYAML                       6.0.2
# pyzmq                        26.3.0
# referencing                  0.35.1
# requests                     2.32.3
# requests-oauthlib            2.0.0
# rich                         13.9.4
# rpds-py                      0.20.1
# rsa                          4.9
# ruff                         0.10.0
# scikit-learn                 1.3.2
# scipy                        1.10.1
# seaborn                      0.13.2
# semantic-version             2.10.0
# setuptools                   49.2.1
# shellingham                  1.5.4
# six                          1.17.0
# smmap                        5.0.2
# sniffio                      1.3.1
# sounddevice                  0.5.1
# soupsieve                    2.6
# sqlparse                     0.5.1
# stack-data                   0.6.3
# starlette                    0.44.0
# statsmodels                  0.14.1
# streamlit                    1.40.1
# tenacity                     9.0.0
# tensorboard                  2.12.3
# tensorboard-data-server      0.7.2
# tensorflow                   2.12.0
# tensorflow-estimator         2.12.0
# tensorflow-intel             2.12.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# threadpoolctl                3.5.0
# toml                         0.10.2
# tomlkit                      0.12.0
# tornado                      6.4.2
# tqdm                         4.67.1
# traitlets                    5.14.3
# typer                        0.15.2
# typing_extensions            4.12.2
# tzdata                       2024.2
# urllib3                      2.2.3
# uvicorn                      0.33.0
# watchdog                     4.0.2
# wcwidth                      0.2.13
# websockets                   12.0
# Werkzeug                     3.0.6
# wheel                        0.45.1
# wrapt                        1.14.1
# yfinance                     0.2.54
# zipp                         3.20.2
# Note: you may need to restart the kernel to use updated packages.

# %%
screen_width, screen_height = pyautogui.size()
mouse = Controller()

mphands = mp.solutions.hands
hands = mphands.Hands(
    static_image_mode = False, # no image hands needed to detect 
    model_complexity = 1,
    min_detection_confidence = 0.7, # in order to identify a thing in display as a hand  the accuracy must be more min 70%
    min_tracking_confidence = 0.7,  # in order to track the movement of hand min accurac of 70 % required 
    max_num_hands = 1 # is display contain more number of hand it need to recognize only one 
)

# %%
def move_mouse(index_finger_tip):
    if index_finger_tip is not None:
        x = int(index_finger_tip.x * 1000)  # the position value will be in a between a 0 and 1 but we need  value like less than 50 like that so we multiply it by 1000
        y = int(index_finger_tip.y * 1000)
        pyautogui.moveTo(x,y)

# %%
def find_finger_tip(processed):
    if processed.multi_hand_landmarks:
        hand_landmarks = processed.multi_hand_landmarks[0]
        return hand_landmarks.landmark[mphands.HandLandmark.INDEX_FINGER_TIP]
    return None

# %%
def is_left_click(landmarks_list, thumb_index_dist):
    return (util.get_angle(landmarks_list[5], landmarks_list[6], landmarks_list[8]) < 30  and 
            util.get_angle(landmarks_list[9], landmarks_list[10], landmarks_list[12]) > 50 and 
            util.get_angle(landmarks_list[17], landmarks_list[18], landmarks_list[20]) > 90 and
            # thumb_indextip_dist > 40 and
            thumb_index_dist > 75
            )


def is_right_click(landmarks_list, thumb_index_dist):
    return (util.get_angle(landmarks_list[5], landmarks_list[6], landmarks_list[8]) > 50 and 
            util.get_angle(landmarks_list[9], landmarks_list[10], landmarks_list[12]) < 30  and 
            util.get_angle(landmarks_list[17], landmarks_list[18], landmarks_list[20]) > 90 and
            thumb_index_dist > 75
            )

def is_double_click(landmarks_list, thumb_index_dist):
    return (util.get_angle(landmarks_list[5], landmarks_list[6], landmarks_list[8]) < 50 and 
            util.get_angle(landmarks_list[9], landmarks_list[10], landmarks_list[12]) < 50 and 
            thumb_index_dist > 75
            )

def is_screenshot(landmarks_list, thumb_index_dist):
    return (util.get_angle(landmarks_list[5], landmarks_list[6], landmarks_list[8]) < 50 and 
            util.get_angle(landmarks_list[9], landmarks_list[10], landmarks_list[12]) < 50 and 
            thumb_index_dist < 75
            )

# def is_drag(landmarks_list, thumb_mid_dist):
#     return (util.get_angle(landmarks_list[17], landmarks_list[18], landmarks_list[20]) > 90 and
#             util.get_angle(landmarks_list[5], landmarks_list[6], landmarks_list[8]) > 50 and 
#             thumb_mid_dist < 30
            # )

# %%
def detect_gestures(frame, landmarks_list, processed):
    if len(landmarks_list)>=21:
        index_finger_tip = find_finger_tip(processed)
        thumb_index_dist = util.get_distance([landmarks_list[4],landmarks_list[5]])
        # thumb_mid_dist = util.get_distance([landmarks_list[4],landmarks_list[8]])
        # thumb_indextip_dist = util.get_distance([landmarks_list[8],landmarks_list[4]])
        # thumb_midtip_dist = util.get_distance([landmarks_list[12],landmarks_list[1]])

        if thumb_index_dist < 30 and util.get_angle(landmarks_list[5],landmarks_list[6],landmarks_list[8]) > 90 :
            move_mouse(index_finger_tip) 

        
        # left click
        elif is_left_click(landmarks_list, thumb_index_dist): 
            mouse.press(Button.left)
            mouse.release(Button.left)

        # right click
        elif is_right_click(landmarks_list, thumb_index_dist):
            mouse.press(Button.right)
            mouse.release(Button.right)


        # double click
        elif is_double_click(landmarks_list, thumb_index_dist): 
            pyautogui.doubleClick()



        # screenshot
        elif is_screenshot(landmarks_list, thumb_index_dist):
            im1 = pyautogui.screenshot()
            label = random.randint(1, 1000)
            im1.save(f'my_screenshot_{label}.png')

        # elif is_drag(landmarks_list,thumb_mid_dist):
        #      if index_finger_tip is not None:
        #         x = int(index_finger_tip.x * 1000)  # the position value will be in a between a 0 and 1 but we need  value like less than 50 like that so we multiply it by 1000
        #         y = int(index_finger_tip.y * 1000)
        #         pyautogui.dragTo(x,y)

# %%
pyautogui.FAILSAFE = False

# %%
def  main():
    cap = cv2.VideoCapture(0)
    draw = mp.solutions.drawing_utils  # to draw a hand marks and all
    try:
        while cap.isOpened():
            ret,frame = cap.read()   #ret is returning a boolean value if abel to capture a video it will return true else false
            
            if not ret:    #if ret is false
                print ('not abel to open a video')
            frame = cv2.flip(frame,1) # mirror the video that will visible like we are viewing a camera
            framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) # to convert the color from bgr to rgb
            
            processed = hands.process(framergb)  # to process the color changed hand and store in a variable
            landmarks_list = []
            
            if processed.multi_hand_landmarks:   # if anything is processed then 
                hand_landmarks = processed.multi_hand_landmarks[0]   # select any one of the processed hand land marks and store it in a variable
                draw.draw_landmarks(frame, hand_landmarks, mphands.HAND_CONNECTIONS) # after identifying a landmarks on a hand join them 
                 
                for lm in hand_landmarks.landmark:
                    landmarks_list.append((lm.x, lm.y))

                
                # print(landmarks_list)
                
            detect_gestures(frame, landmarks_list, processed)  #calling a function
                
            cv2.imshow('Frame',frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):  #wait for 1sec for each frame and 0xff says that a keyboard input : if keyboard input is q then video capturing will end
                break
                
    finally:
        cap.release()
        cv2.destroyAllWindows()
        
if __name__ == '__main__':  #file wont run any where except this main file
    main()

# %%
brd = int(input("enter your DOB : "))
cur = int(2024)
if brd < 2024 :
    age = cur - brd
    print("the age is : ", age)
else :
    print("invalid DOB ! ")
